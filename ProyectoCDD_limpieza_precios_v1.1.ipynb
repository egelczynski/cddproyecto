# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import sklearn.preprocessing

# %%
data = pd.read_csv("data.csv")
edit = data.copy()
# Out:
# C:\Users\ssola\AppData\Local\Temp\ipykernel_16800\492614709.py:1: DtypeWarning: Columns (1) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv("data.csv")

# %% [markdown]
# ## Limpieza de Datos

# %% [markdown]
# ### Precio

# %%
dfprecio = edit.copy()
dfprecio['precio'].isna().sum() #cantidad chica de valores faltantes, estos datos deben eliminarse para seguir con el modelo
# Out:
# 121

# %%
dfprecio[dfprecio['precio'].isna()==True]
# Out:
#       nombre_inmueble                                     aviso precio  \
# 95473             NaN   https://www.gallito.com.uy/tel:24807130    NaN
# 95479             NaN     https://www.gallito.com.uy/error.html    NaN
# 95482             NaN   https://www.gallito.com.uy/tel:26963000    NaN
# 95490             NaN  https://www.gallito.com.uy/tel:093389494    NaN
# 95492             NaN   https://www.gallito.com.uy/tel:27117252    NaN
# ...               ...                                       ...    ...
# 96550             NaN  https://www.gallito.com.uy/tel:099904560    NaN
# 96555             NaN  https://www.gallito.com.uy/tel:096329700    NaN
# 96559             NaN  https://www.gallito.com.uy/tel:097039888    NaN
# 96566             NaN  https://www.gallito.com.uy/tel:099961012    NaN
# 96575             NaN  https://www.gallito.com.uy/tel:097122916    NaN
#
#       superficie tipo dormitorios direccion barrio negocio  \
# 95473        NaN  NaN         NaN       NaN    NaN     NaN
# 95479        NaN  NaN         NaN       NaN    NaN     NaN
# 95482        NaN  NaN         NaN       NaN    NaN     NaN
# 95490        NaN  NaN         NaN       NaN    NaN     NaN
# 95492        NaN  NaN         NaN       NaN    NaN     NaN
# ...          ...  ...         ...       ...    ...     ...
# 96550        NaN  NaN         NaN       NaN    NaN     NaN
# 96555        NaN  NaN         NaN       NaN    NaN     NaN
# 96559        NaN  NaN         NaN       NaN    NaN     NaN
# 96566        NaN  NaN         NaN       NaN    NaN     NaN
# 96575        NaN  NaN         NaN       NaN    NaN     NaN
#
#                      fecha
# 95473  2021-09-23 00:00:00
# 95479  2021-09-23 00:00:00
# 95482  2021-09-23 00:00:00
# 95490  2021-09-23 00:00:00
# 95492  2021-09-23 00:00:00
# ...                    ...
# 96550  2021-12-07 00:00:00
# 96555  2021-12-07 00:00:00
# 96559  2021-12-07 00:00:00
# 96566  2021-12-07 00:00:00
# 96575  2021-12-07 00:00:00
#
# [121 rows x 10 columns]

# %%
NaN_precios  = dfprecio['precio'].isna()
NaN_precios_loc = NaN_precios[NaN_precios==True].index.values
NaN_precios_loc
# Out:
# array([95473, 95479, 95482, 95490, 95492, 95497, 95502, 95511, 95516,
#        95523, 95527, 95531, 95543, 95553, 95556, 95565, 95577, 95582,
#        95602, 95604, 95614, 95618, 95620, 95640, 95647, 95654, 95665,
#        95671, 95677, 95683, 95685, 95688, 95698, 95701, 95713, 95719,
#        95722, 95724, 95755, 95769, 95788, 95889, 95890, 95893, 95894,
#        95927, 95930, 95950, 95961, 95983, 96000, 96016, 96019, 96034,
#        96043, 96045, 96047, 96081, 96087, 96089, 96096, 96097, 96101,
#        96112, 96116, 96120, 96128, 96136, 96145, 96153, 96158, 96169,
#        96171, 96195, 96197, 96204, 96216, 96220, 96226, 96234, 96246,
#        96257, 96260, 96268, 96273, 96278, 96284, 96291, 96293, 96311,
#        96322, 96329, 96343, 96350, 96352, 96365, 96370, 96377, 96384,
#        96386, 96401, 96402, 96404, 96435, 96441, 96444, 96447, 96472,
#        96480, 96484, 96487, 96497, 96505, 96508, 96519, 96529, 96550,
#        96555, 96559, 96566, 96575], dtype=int64)

# %%
dfprecio.iloc[NaN_precios_loc] #son filas sin valores **IDENTIFICAR ERROR**
# Out:
#       nombre_inmueble                                     aviso precio  \
# 95473             NaN   https://www.gallito.com.uy/tel:24807130    NaN
# 95479             NaN     https://www.gallito.com.uy/error.html    NaN
# 95482             NaN   https://www.gallito.com.uy/tel:26963000    NaN
# 95490             NaN  https://www.gallito.com.uy/tel:093389494    NaN
# 95492             NaN   https://www.gallito.com.uy/tel:27117252    NaN
# ...               ...                                       ...    ...
# 96550             NaN  https://www.gallito.com.uy/tel:099904560    NaN
# 96555             NaN  https://www.gallito.com.uy/tel:096329700    NaN
# 96559             NaN  https://www.gallito.com.uy/tel:097039888    NaN
# 96566             NaN  https://www.gallito.com.uy/tel:099961012    NaN
# 96575             NaN  https://www.gallito.com.uy/tel:097122916    NaN
#
#       superficie tipo dormitorios direccion barrio negocio  \
# 95473        NaN  NaN         NaN       NaN    NaN     NaN
# 95479        NaN  NaN         NaN       NaN    NaN     NaN
# 95482        NaN  NaN         NaN       NaN    NaN     NaN
# 95490        NaN  NaN         NaN       NaN    NaN     NaN
# 95492        NaN  NaN         NaN       NaN    NaN     NaN
# ...          ...  ...         ...       ...    ...     ...
# 96550        NaN  NaN         NaN       NaN    NaN     NaN
# 96555        NaN  NaN         NaN       NaN    NaN     NaN
# 96559        NaN  NaN         NaN       NaN    NaN     NaN
# 96566        NaN  NaN         NaN       NaN    NaN     NaN
# 96575        NaN  NaN         NaN       NaN    NaN     NaN
#
#                      fecha
# 95473  2021-09-23 00:00:00
# 95479  2021-09-23 00:00:00
# 95482  2021-09-23 00:00:00
# 95490  2021-09-23 00:00:00
# 95492  2021-09-23 00:00:00
# ...                    ...
# 96550  2021-12-07 00:00:00
# 96555  2021-12-07 00:00:00
# 96559  2021-12-07 00:00:00
# 96566  2021-12-07 00:00:00
# 96575  2021-12-07 00:00:00
#
# [121 rows x 10 columns]

# %% [markdown]
# **IDENTIFICAR ERROR**

# %%
dfprecio = dfprecio.drop(index= NaN_precios_loc)

# %%
dfprecio
# Out:
#                                          nombre_inmueble     aviso  \
# 0             CASAS-ALQUILER-TEMPORAL-PUNTA-COLORADA-034  16579724
# 1      Alquilo Apto. 2 Dorm. Vista , 2 da Enero y Mar...  16735528
# 2                   Casa en Cerro del Burro "MIRADOR II"  13795860
# 3      Oficina Alquiler World Trade Center -WTC- Poci...  15655688
# 4                              Terreno en Punta Colorada  12805785
# ...                                                  ...       ...
# 96578  LOCALES-COMERCIALES-ALQUILER-ANUAL-PIRIAPOLIS-...  18610881
# 96579                Casa en Punta Colorada "LA VISTOSA"  17710617
# 96580                  Casa en San Francisco "GABIMAR I"  12804460
# 96581                      CASAS-VENTA-SAN-FRANCISCO-289  18611010
# 96582                     CASAS-VENTA-PLAYA-HERMOSA-1221  18610480
#
#              precio superficie         tipo    dormitorios  \
# 0         U$S 1.750    600 Mts         Casa  2 dormitorios
# 1            $U 800        NaN  Apartamento  2 dormitorios
# 2       U$S 100.000    300 Mts         Casa   1 dormitorio
# 3         U$S 1.600        NaN      Oficina            NaN
# 4        U$S 67.000    615 Mts      Terreno            NaN
# ...             ...        ...          ...            ...
# 96578     $U 22.000        NaN        Local            NaN
# 96579   U$S 120.000   1000 Mts         Casa   1 dormitorio
# 96580     U$S 1.600    500 Mts         Casa  2 dormitorios
# 96581   U$S 190.000    532 Mts         Casa  3 dormitorios
# 96582   U$S 175.000    434 Mts         Casa  2 dormitorios
#
#                                                direccion          barrio  \
# 0      Av. Primera entre Rambla Costanera y 8 Guazubi...  Punta Colorada
# 1                         Mi hijo el doctor y En Familia  Punta Del Este
# 2                                  ... y Cerro del burro      Piriápolis
# 3                                            ... y Buceo           Buceo
# 4                              TE201282 y Punta colorada  Punta Colorada
# ...                                                  ...             ...
# 96578                 Tucumán entre Sierra y Sanabria y       Piriápolis
# 96579                               ... y Punta colorada      Piriápolis
# 96580                                ... y San francisco      Piriápolis
# 96581                           25 Cardenal y 6 Cisne y       Piriápolis
# 96582              Calle 62 entre Calle 21 y Calle 17 y    Playa Hermosa
#
#                    negocio                fecha
# 0      Alquiler temporario  2021-01-03 00:00:00
# 1      Alquiler temporario  2021-01-03 00:00:00
# 2                    Venta  2021-01-03 00:00:00
# 3                 Alquiler  2021-01-03 00:00:00
# 4                    Venta  2021-01-03 00:00:00
# ...                    ...                  ...
# 96578             Alquiler  2021-12-07 00:00:00
# 96579                Venta  2021-12-07 00:00:00
# 96580  Alquiler temporario  2021-12-07 00:00:00
# 96581                Venta  2021-12-07 00:00:00
# 96582                Venta  2021-12-07 00:00:00
#
# [96462 rows x 10 columns]

# %%
dfprecio = dfprecio.reset_index(drop=True)
dfprecio
# Out:
#                                          nombre_inmueble     aviso  \
# 0             CASAS-ALQUILER-TEMPORAL-PUNTA-COLORADA-034  16579724
# 1      Alquilo Apto. 2 Dorm. Vista , 2 da Enero y Mar...  16735528
# 2                   Casa en Cerro del Burro "MIRADOR II"  13795860
# 3      Oficina Alquiler World Trade Center -WTC- Poci...  15655688
# 4                              Terreno en Punta Colorada  12805785
# ...                                                  ...       ...
# 96457  LOCALES-COMERCIALES-ALQUILER-ANUAL-PIRIAPOLIS-...  18610881
# 96458                Casa en Punta Colorada "LA VISTOSA"  17710617
# 96459                  Casa en San Francisco "GABIMAR I"  12804460
# 96460                      CASAS-VENTA-SAN-FRANCISCO-289  18611010
# 96461                     CASAS-VENTA-PLAYA-HERMOSA-1221  18610480
#
#              precio superficie         tipo    dormitorios  \
# 0         U$S 1.750    600 Mts         Casa  2 dormitorios
# 1            $U 800        NaN  Apartamento  2 dormitorios
# 2       U$S 100.000    300 Mts         Casa   1 dormitorio
# 3         U$S 1.600        NaN      Oficina            NaN
# 4        U$S 67.000    615 Mts      Terreno            NaN
# ...             ...        ...          ...            ...
# 96457     $U 22.000        NaN        Local            NaN
# 96458   U$S 120.000   1000 Mts         Casa   1 dormitorio
# 96459     U$S 1.600    500 Mts         Casa  2 dormitorios
# 96460   U$S 190.000    532 Mts         Casa  3 dormitorios
# 96461   U$S 175.000    434 Mts         Casa  2 dormitorios
#
#                                                direccion          barrio  \
# 0      Av. Primera entre Rambla Costanera y 8 Guazubi...  Punta Colorada
# 1                         Mi hijo el doctor y En Familia  Punta Del Este
# 2                                  ... y Cerro del burro      Piriápolis
# 3                                            ... y Buceo           Buceo
# 4                              TE201282 y Punta colorada  Punta Colorada
# ...                                                  ...             ...
# 96457                 Tucumán entre Sierra y Sanabria y       Piriápolis
# 96458                               ... y Punta colorada      Piriápolis
# 96459                                ... y San francisco      Piriápolis
# 96460                           25 Cardenal y 6 Cisne y       Piriápolis
# 96461              Calle 62 entre Calle 21 y Calle 17 y    Playa Hermosa
#
#                    negocio                fecha
# 0      Alquiler temporario  2021-01-03 00:00:00
# 1      Alquiler temporario  2021-01-03 00:00:00
# 2                    Venta  2021-01-03 00:00:00
# 3                 Alquiler  2021-01-03 00:00:00
# 4                    Venta  2021-01-03 00:00:00
# ...                    ...                  ...
# 96457             Alquiler  2021-12-07 00:00:00
# 96458                Venta  2021-12-07 00:00:00
# 96459  Alquiler temporario  2021-12-07 00:00:00
# 96460                Venta  2021-12-07 00:00:00
# 96461                Venta  2021-12-07 00:00:00
#
# [96462 rows x 10 columns]

# %%
dfprecio['precio'] = dfprecio['precio'].replace('\$','', regex = True)
dfprecio
# Out:
#                                          nombre_inmueble     aviso  \
# 0             CASAS-ALQUILER-TEMPORAL-PUNTA-COLORADA-034  16579724
# 1      Alquilo Apto. 2 Dorm. Vista , 2 da Enero y Mar...  16735528
# 2                   Casa en Cerro del Burro "MIRADOR II"  13795860
# 3      Oficina Alquiler World Trade Center -WTC- Poci...  15655688
# 4                              Terreno en Punta Colorada  12805785
# ...                                                  ...       ...
# 96457  LOCALES-COMERCIALES-ALQUILER-ANUAL-PIRIAPOLIS-...  18610881
# 96458                Casa en Punta Colorada "LA VISTOSA"  17710617
# 96459                  Casa en San Francisco "GABIMAR I"  12804460
# 96460                      CASAS-VENTA-SAN-FRANCISCO-289  18611010
# 96461                     CASAS-VENTA-PLAYA-HERMOSA-1221  18610480
#
#             precio superficie         tipo    dormitorios  \
# 0         US 1.750    600 Mts         Casa  2 dormitorios
# 1            U 800        NaN  Apartamento  2 dormitorios
# 2       US 100.000    300 Mts         Casa   1 dormitorio
# 3         US 1.600        NaN      Oficina            NaN
# 4        US 67.000    615 Mts      Terreno            NaN
# ...            ...        ...          ...            ...
# 96457     U 22.000        NaN        Local            NaN
# 96458   US 120.000   1000 Mts         Casa   1 dormitorio
# 96459     US 1.600    500 Mts         Casa  2 dormitorios
# 96460   US 190.000    532 Mts         Casa  3 dormitorios
# 96461   US 175.000    434 Mts         Casa  2 dormitorios
#
#                                                direccion          barrio  \
# 0      Av. Primera entre Rambla Costanera y 8 Guazubi...  Punta Colorada
# 1                         Mi hijo el doctor y En Familia  Punta Del Este
# 2                                  ... y Cerro del burro      Piriápolis
# 3                                            ... y Buceo           Buceo
# 4                              TE201282 y Punta colorada  Punta Colorada
# ...                                                  ...             ...
# 96457                 Tucumán entre Sierra y Sanabria y       Piriápolis
# 96458                               ... y Punta colorada      Piriápolis
# 96459                                ... y San francisco      Piriápolis
# 96460                           25 Cardenal y 6 Cisne y       Piriápolis
# 96461              Calle 62 entre Calle 21 y Calle 17 y    Playa Hermosa
#
#                    negocio                fecha
# 0      Alquiler temporario  2021-01-03 00:00:00
# 1      Alquiler temporario  2021-01-03 00:00:00
# 2                    Venta  2021-01-03 00:00:00
# 3                 Alquiler  2021-01-03 00:00:00
# 4                    Venta  2021-01-03 00:00:00
# ...                    ...                  ...
# 96457             Alquiler  2021-12-07 00:00:00
# 96458                Venta  2021-12-07 00:00:00
# 96459  Alquiler temporario  2021-12-07 00:00:00
# 96460                Venta  2021-12-07 00:00:00
# 96461                Venta  2021-12-07 00:00:00
#
# [96462 rows x 10 columns]

# %%
uyu = dfprecio['precio'].str.contains('U ', case=True, regex=True)

# %%
UYUloc = uyu[uyu==True].index.values
len(UYUloc)
# Out:
# 9584

# %%
dfprecio['precio'][UYUloc] = dfprecio['precio'].iloc[UYUloc].str.replace('U','')

# %%
dfprecio['precio'] = dfprecio['precio'].str.replace('US ','')
dfprecio['precio'] = dfprecio['precio'].str.replace('.','', regex = True)
dfprecio['precio'] = dfprecio['precio'].astype(str).astype(int).astype(float)

# %%
pip install yfinance
# Out:
# Requirement already satisfied: yfinance in c:\users\ssola\miniconda3\lib\site-packages (0.1.72)
# Requirement already satisfied: multitasking>=0.0.7 in c:\users\ssola\miniconda3\lib\site-packages (from yfinance) (0.0.10)
# Requirement already satisfied: pandas>=0.24.0 in c:\users\ssola\miniconda3\lib\site-packages (from yfinance) (1.4.2)
# Requirement already satisfied: lxml>=4.5.1 in c:\users\ssola\miniconda3\lib\site-packages (from yfinance) (4.9.0)
# Requirement already satisfied: requests>=2.26 in c:\users\ssola\miniconda3\lib\site-packages (from yfinance) (2.27.1)
# Requirement already satisfied: numpy>=1.15 in c:\users\ssola\miniconda3\lib\site-packages (from yfinance) (1.22.4)
# Requirement already satisfied: pytz>=2020.1 in c:\users\ssola\miniconda3\lib\site-packages (from pandas>=0.24.0->yfinance) (2022.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\ssola\miniconda3\lib\site-packages (from pandas>=0.24.0->yfinance) (2.8.2)
# Requirement already satisfied: six>=1.5 in c:\users\ssola\miniconda3\lib\site-packages (from python-dateutil>=2.8.1->pandas>=0.24.0->yfinance) (1.16.0)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\ssola\miniconda3\lib\site-packages (from requests>=2.26->yfinance) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\ssola\miniconda3\lib\site-packages (from requests>=2.26->yfinance) (3.3)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\ssola\miniconda3\lib\site-packages (from requests>=2.26->yfinance) (1.26.9)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\ssola\miniconda3\lib\site-packages (from requests>=2.26->yfinance) (2022.5.18.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
import yfinance as yahooFinance
from datetime import datetime, timedelta

# %%
def convert_currency(src, dst, amount):
    # construct the currency pair symbol
    symbol = f"{src}{dst}=X"
    FX = yahooFinance.Ticker(symbol)
    
    # extract minute data of the recent 2 days
    latest_data = FX.history(period = '1d')
    
    # get the latest datetime
    last_updated_datetime = latest_data.index[-1].to_pydatetime()
    
    # get the latest price
    latest_price = latest_data['Close'].iloc[-1]
    
    # return the latest datetime with the converted amount
    return latest_price * amount

# %%
convert_currency('UYU','USD',100)
# Out:
# 2.5080256164073944

# %%
# dfprecio['precio'][UYUloc].apply(lambda x: convert_currency('UYU','USD',x))
# Supuesto Cotizacion

# %%
dfprecio['precio'][UYUloc].apply(lambda x: x/40)
dfprecio
# Out:
#                                          nombre_inmueble     aviso    precio  \
# 0             CASAS-ALQUILER-TEMPORAL-PUNTA-COLORADA-034  16579724    1750.0
# 1      Alquilo Apto. 2 Dorm. Vista , 2 da Enero y Mar...  16735528      20.0
# 2                   Casa en Cerro del Burro "MIRADOR II"  13795860  100000.0
# 3      Oficina Alquiler World Trade Center -WTC- Poci...  15655688    1600.0
# 4                              Terreno en Punta Colorada  12805785   67000.0
# ...                                                  ...       ...       ...
# 96457  LOCALES-COMERCIALES-ALQUILER-ANUAL-PIRIAPOLIS-...  18610881     550.0
# 96458                Casa en Punta Colorada "LA VISTOSA"  17710617  120000.0
# 96459                  Casa en San Francisco "GABIMAR I"  12804460    1600.0
# 96460                      CASAS-VENTA-SAN-FRANCISCO-289  18611010  190000.0
# 96461                     CASAS-VENTA-PLAYA-HERMOSA-1221  18610480  175000.0
#
#       superficie         tipo    dormitorios  \
# 0        600 Mts         Casa  2 dormitorios
# 1            NaN  Apartamento  2 dormitorios
# 2        300 Mts         Casa   1 dormitorio
# 3            NaN      Oficina            NaN
# 4        615 Mts      Terreno            NaN
# ...          ...          ...            ...
# 96457        NaN        Local            NaN
# 96458   1000 Mts         Casa   1 dormitorio
# 96459    500 Mts         Casa  2 dormitorios
# 96460    532 Mts         Casa  3 dormitorios
# 96461    434 Mts         Casa  2 dormitorios
#
#                                                direccion          barrio  \
# 0      Av. Primera entre Rambla Costanera y 8 Guazubi...  Punta Colorada
# 1                         Mi hijo el doctor y En Familia  Punta Del Este
# 2                                  ... y Cerro del burro      Piriápolis
# 3                                            ... y Buceo           Buceo
# 4                              TE201282 y Punta colorada  Punta Colorada
# ...                                                  ...             ...
# 96457                 Tucumán entre Sierra y Sanabria y       Piriápolis
# 96458                               ... y Punta colorada      Piriápolis
# 96459                                ... y San francisco      Piriápolis
# 96460                           25 Cardenal y 6 Cisne y       Piriápolis
# 96461              Calle 62 entre Calle 21 y Calle 17 y    Playa Hermosa
#
#                    negocio                fecha
# 0      Alquiler temporario  2021-01-03 00:00:00
# 1      Alquiler temporario  2021-01-03 00:00:00
# 2                    Venta  2021-01-03 00:00:00
# 3                 Alquiler  2021-01-03 00:00:00
# 4                    Venta  2021-01-03 00:00:00
# ...                    ...                  ...
# 96457             Alquiler  2021-12-07 00:00:00
# 96458                Venta  2021-12-07 00:00:00
# 96459  Alquiler temporario  2021-12-07 00:00:00
# 96460                Venta  2021-12-07 00:00:00
# 96461                Venta  2021-12-07 00:00:00
#
# [96462 rows x 10 columns]

# %%
dfprecio.rename(columns = {'precio':'precio U$S'}, inplace = True)
dfprecio
# Out:
#                                          nombre_inmueble     aviso  \
# 0             CASAS-ALQUILER-TEMPORAL-PUNTA-COLORADA-034  16579724
# 1      Alquilo Apto. 2 Dorm. Vista , 2 da Enero y Mar...  16735528
# 2                   Casa en Cerro del Burro "MIRADOR II"  13795860
# 3      Oficina Alquiler World Trade Center -WTC- Poci...  15655688
# 4                              Terreno en Punta Colorada  12805785
# ...                                                  ...       ...
# 96457  LOCALES-COMERCIALES-ALQUILER-ANUAL-PIRIAPOLIS-...  18610881
# 96458                Casa en Punta Colorada "LA VISTOSA"  17710617
# 96459                  Casa en San Francisco "GABIMAR I"  12804460
# 96460                      CASAS-VENTA-SAN-FRANCISCO-289  18611010
# 96461                     CASAS-VENTA-PLAYA-HERMOSA-1221  18610480
#
#        precio U$S superficie         tipo    dormitorios  \
# 0          1750.0    600 Mts         Casa  2 dormitorios
# 1            20.0        NaN  Apartamento  2 dormitorios
# 2        100000.0    300 Mts         Casa   1 dormitorio
# 3          1600.0        NaN      Oficina            NaN
# 4         67000.0    615 Mts      Terreno            NaN
# ...           ...        ...          ...            ...
# 96457       550.0        NaN        Local            NaN
# 96458    120000.0   1000 Mts         Casa   1 dormitorio
# 96459      1600.0    500 Mts         Casa  2 dormitorios
# 96460    190000.0    532 Mts         Casa  3 dormitorios
# 96461    175000.0    434 Mts         Casa  2 dormitorios
#
#                                                direccion          barrio  \
# 0      Av. Primera entre Rambla Costanera y 8 Guazubi...  Punta Colorada
# 1                         Mi hijo el doctor y En Familia  Punta Del Este
# 2                                  ... y Cerro del burro      Piriápolis
# 3                                            ... y Buceo           Buceo
# 4                              TE201282 y Punta colorada  Punta Colorada
# ...                                                  ...             ...
# 96457                 Tucumán entre Sierra y Sanabria y       Piriápolis
# 96458                               ... y Punta colorada      Piriápolis
# 96459                                ... y San francisco      Piriápolis
# 96460                           25 Cardenal y 6 Cisne y       Piriápolis
# 96461              Calle 62 entre Calle 21 y Calle 17 y    Playa Hermosa
#
#                    negocio                fecha
# 0      Alquiler temporario  2021-01-03 00:00:00
# 1      Alquiler temporario  2021-01-03 00:00:00
# 2                    Venta  2021-01-03 00:00:00
# 3                 Alquiler  2021-01-03 00:00:00
# 4                    Venta  2021-01-03 00:00:00
# ...                    ...                  ...
# 96457             Alquiler  2021-12-07 00:00:00
# 96458                Venta  2021-12-07 00:00:00
# 96459  Alquiler temporario  2021-12-07 00:00:00
# 96460                Venta  2021-12-07 00:00:00
# 96461                Venta  2021-12-07 00:00:00
#
# [96462 rows x 10 columns]
